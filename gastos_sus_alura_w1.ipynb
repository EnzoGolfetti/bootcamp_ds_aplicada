# %% [markdown]
# <a href="https://colab.research.google.com/github/EnzoGolfetti/bootcamp_ds_aplicada/blob/main/gastos_sus_alura_w1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dados do registro civil - Módulo 1 Bootcamp Data Science Aplicada Alura

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#alguns parâmetros importantes do Pandas principalmente para dados em formato Br
#enconding = pode ser que os dados não consigam ser interpretados pelo utf-8, ai temos que encodar provavelmente em latin1
#skiprows exclui linhas que podem ser problemáticas ou que são apenas informações inúteis que não servem para os dados
#skipfooter serve para tirar esses rodapés que também são apenas informações
#thousands é para definir qual o separador dos milhares
#decimal define qual o separador de casas decimais

dados = pd.read_csv('/content/gastos_registro_civil_proced_alura.csv', sep=';', skiprows=3, encoding='latin1', skipfooter=12,
                    thousands = ".", decimal = ",")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
dados.head()
# Out:
#   Unidade da Federação     2008/Jan  ...     2020/Ago         Total
# 0          11 Rondônia   1388528.39  ...  10285455.78  9.291297e+08
# 1              12 Acre    902416.00  ...            -  4.206680e+08
# 2          13 Amazonas   4735529.42  ...  14726443.67  1.771655e+09
# 3           14 Roraima    657889.53  ...   2826486.18  3.050109e+08
# 4              15 Pará  18864744.11  ...  39911193.02  4.437116e+09
#
# [5 rows x 154 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 154 entries, Unidade da Federação to Total
# dtypes: float64(151), object(3)
# memory usage: 32.6+ KB

# %%
dados.describe()
# Out:
#            2008/Jan      2008/Fev  ...      2020/Jul         Total
# count  2.700000e+01  2.700000e+01  ...  2.700000e+01  2.700000e+01
# mean   1.512685e+07  2.271016e+07  ...  5.449551e+07  5.993732e+09
# std    1.915919e+07  3.087944e+07  ...  7.397429e+07  8.057807e+09
# min    6.578895e+05  7.779393e+05  ...  3.015488e+06  2.916380e+08
# 25%    4.740724e+06  7.060732e+06  ...  1.712162e+07  1.904289e+09
# 50%    7.985142e+06  1.007993e+07  ...  2.690244e+07  2.477372e+09
# 75%    1.768483e+07  2.569327e+07  ...  6.883031e+07  7.685527e+09
# max    9.167847e+07  1.486775e+08  ...  3.667212e+08  3.892955e+10
#
# [8 rows x 151 columns]

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2020/Abr     41013660.39
# 2020/Mai     44193633.75
# 2020/Jun     47329994.46
# 2020/Jul     54495511.57
# Total      5993731798.30
# Length: 151, dtype: float64

# %%
#plotando um gráfico de barras mais simples pelo .plot()
import matplotlib.ticker as ticker
ax = dados.plot(x='Unidade da Federação', y='2008/Ago', kind='bar', figsize=(12,6))
ax.set_title('Gastos com tratamento hospitalar nos estados')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

# %%
dados.tail()
# Out:
#      Unidade da Federação    2008/Jan  ...      2020/Ago          Total
# 22   43 Rio Grande do Sul 30931325.46  ...  101374341.51 11958647088.33
# 23  50 Mato Grosso do Sul  5377392.11  ...   19241624.02  2172157981.36
# 24         51 Mato Grosso  4795299.01  ...   17790649.87  2036923784.59
# 25               52 Goiás 15310637.29  ...   43984702.05  4657350310.70
# 26    53 Distrito Federal  4745919.19  ...   26526196.39  2429933198.76
#
# [5 rows x 154 columns]

# %%
dados.head()
# Out:
#   Unidade da Federação    2008/Jan  ...     2020/Ago         Total
# 0          11 Rondônia  1388528.39  ...  10285455.78  929129659.72
# 1              12 Acre   902416.00  ...            -  420668039.63
# 2          13 Amazonas  4735529.42  ...  14726443.67 1771654871.23
# 3           14 Roraima   657889.53  ...   2826486.18  305010883.18
# 4              15 Pará 18864744.11  ...  39911193.02 4437115730.71
#
# [5 rows x 154 columns]

# %%
data = dados.drop(labels=[1], axis=0)

# %%
data.head()
# Out:
#   Unidade da Federação    2008/Jan  ...     2020/Ago         Total
# 0          11 Rondônia  1388528.39  ...  10285455.78  929129659.72
# 2          13 Amazonas  4735529.42  ...  14726443.67 1771654871.23
# 3           14 Roraima   657889.53  ...   2826486.18  305010883.18
# 4              15 Pará 18864744.11  ...  39911193.02 4437115730.71
# 5             16 Amapá  1120973.34  ...   2942273.94  291637984.75
#
# [5 rows x 154 columns]

# %%
data['2020/Ago'] = data['2020/Ago'].astype('float64')

# %%
data['2020/Ago'].mean()
# Out:
# 56505034.29346153

# %%
dados.iloc[1,152] = 56505034.29

# %%
dados.head()
# Out:
#   Unidade da Federação    2008/Jan  ...     2020/Ago         Total
# 0          11 Rondônia  1388528.39  ...  10285455.78  929129659.72
# 1              12 Acre   902416.00  ...  56505034.29  420668039.63
# 2          13 Amazonas  4735529.42  ...  14726443.67 1771654871.23
# 3           14 Roraima   657889.53  ...   2826486.18  305010883.18
# 4              15 Pará 18864744.11  ...  39911193.02 4437115730.71
#
# [5 rows x 154 columns]

# %%
dados['2020/Ago'] = dados['2020/Ago'].astype('float64')

# %%
ax = dados.plot(x='Unidade da Federação', y='2020/Ago', kind='bar', figsize=(12,6))
ax.set_title('Gastos com tratamento hospitalar nos estados')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

# %% [markdown]
# #Dados da base A160 - gastos com saúde

# %%
#alguns parâmetros importantes do Pandas principalmente para dados em formato Br
#enconding = pode ser que os dados não consigam ser interpretados pelo utf-8, ai temos que encodar provavelmente em latin1
#skiprows exclui linhas que podem ser problemáticas ou que são apenas informações inúteis que não servem para os dados
#skipfooter serve para tirar esses rodapés que também são apenas informações
#thousands é para definir qual o separador dos milhares
#decimal define qual o separador de casas decimais

dados = pd.read_csv('/content/gastos_estados_92_2020_alura.csv', sep=';', skiprows=3, encoding='latin1', skipfooter=12,
                    thousands = ".", decimal = ",")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr  ...    2020/Jul     2020/Ago         Total
# 0          11 Rondônia        -        -  ...  7407388.24   3556381.57  929129659.72
# 1              12 Acre        -        -  ...  1163813.08            -  420668039.63
# 2          13 Amazonas        -        -  ... 13358514.02   4726485.73 1771654871.23
# 3           14 Roraima        -        -  ...  2739498.41   1524478.04  305010883.18
# 4              15 Pará        -        -  ... 27618727.51  11559714.54 4437115730.71
#
# [5 rows x 280 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 280 entries, Unidade da Federação to Total
# dtypes: float64(157), object(123)
# memory usage: 59.2+ KB

# %%
dados.describe()
# Out:
#         2007/Ago   2007/Set  ...     2020/Jul          Total
# count      27.00      27.00  ...        27.00          27.00
# mean   304952.77  788145.26  ...  40717083.95  5993724452.01
# std    392806.00 1071747.56  ...  56808984.40  8057775772.23
# min      4113.76   11858.63  ...   1163813.08   291637984.75
# 25%     46580.42  139423.94  ...  12795934.52  1904289327.91
# 50%    179395.82  418053.58  ...  22233542.26  2477372149.60
# 75%    392985.52  969999.75  ...  55331317.58  7685527172.18
# max   1665349.90 4434168.64  ... 282709570.31 38929353900.57
#
# [8 rows x 157 columns]

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %%
col_uso = dados.mean().index.tolist()

# %%
col_uso
# Out:
# ['2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
#  '2012/Dez',
#  '2013/Jan',
#  '2013/Fev',
#  '2013/Mar',
#  '2013/Abr',
#  '2013/Mai',
#  '2013/Jun',
#  '2013/Jul',
#  '2013/Ago',
#  '2013/Set',
#  '2013/Out',
#  '2013/Nov',
#  '2013/Dez',
#  '2014/Jan',
#  '2014/Fev',
#  '2014/Mar',
#  '2014/Abr',
#  '2014/Mai',
#  '2014/Jun',
#  '2014/Jul',
#  '2014/Ago',
#  '2014/Set',
#  '2014/Out',
#  '2014/Nov',
#  '2014/Dez',
#  '2015/Jan',
#  '2015/Fev',
#  '2015/Mar',
#  '2015/Abr',
#  '2015/Mai',
#  '2015/Jun',
#  '2015/Jul',
#  '2015/Ago',
#  '2015/Set',
#  '2015/Out',
#  '2015/Nov',
#  '2015/Dez',
#  '2016/Jan',
#  '2016/Fev',
#  '2016/Mar',
#  '2016/Abr',
#  '2016/Mai',
#  '2016/Jun',
#  '2016/Jul',
#  '2016/Ago',
#  '2016/Set',
#  '2016/Out',
#  '2016/Nov',
#  '2016/Dez',
#  '2017/Jan',
#  '2017/Fev',
#  '2017/Mar',
#  '2017/Abr',
#  '2017/Mai',
#  '2017/Jun',
#  '2017/Jul',
#  '2017/Ago',
#  '2017/Set',
#  '2017/Out',
#  '2017/Nov',
#  '2017/Dez',
#  '2018/Jan',
#  '2018/Fev',
#  '2018/Mar',
#  '2018/Abr',
#  '2018/Mai',
#  '2018/Jun',
#  '2018/Jul',
#  '2018/Ago',
#  '2018/Set',
#  '2018/Out',
#  '2018/Nov',
#  '2018/Dez',
#  '2019/Jan',
#  '2019/Fev',
#  '2019/Mar',
#  '2019/Abr',
#  '2019/Mai',
#  '2019/Jun',
#  '2019/Jul',
#  '2019/Ago',
#  '2019/Set',
#  '2019/Out',
#  '2019/Nov',
#  '2019/Dez',
#  '2020/Jan',
#  '2020/Fev',
#  '2020/Mar',
#  '2020/Abr',
#  '2020/Mai',
#  '2020/Jun',
#  '2020/Jul',
#  'Total']

# %%
col_uso.insert(0, "Unidade da Federação")

# %%
col_uso

# %%
col_uso = dados.loc[:,col_uso]

# %%
col_uso = col_uso.set_index("Unidade da Federação")

# %%
col_uso.head()
# Out:
#                       2007/Ago  2007/Set  ...    2020/Jul         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  7407388.24  929129659.72
# 12 Acre               10470.07  14001.71  ...  1163813.08  420668039.63
# 13 Amazonas           35752.72  45570.64  ... 13358514.02 1771654871.23
# 14 Roraima             4785.91  11858.63  ...  2739498.41  305010883.18
# 15 Pará              181159.29 433414.74  ... 27618727.51 4437115730.71
#
# [5 rows x 157 columns]

# %%
col_uso.T.plot()

# %% [markdown]
# Podemos ver que ter uma linha de Totais está distorcendo o gráfico, vamos remover a linha pra poder visualizar melhor.

# %%
col_uso = col_uso.drop(columns=['Total'])

# %% [markdown]
# Relembrando: o T serve para transpor o dataset, ou seja, inverter as linhas e colunas.

# %%
ax = col_uso.T.plot(figsize=(12,8))
ax.set_title('Gastos do SUS por estado')
plt.legend(bbox_to_anchor=(1.07,1.03), loc='upper left')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.show()

# %% [markdown]
# Escolhendo 5 estados para plotar o mesmo gráfico

# %%
col_uso.index
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
states5 = col_uso.loc[['13 Amazonas', '29 Bahia','53 Distrito Federal', '35 São Paulo', '43 Rio Grande do Sul'],:]

# %%
states5
# Out:
#                        2007/Ago   2007/Set  ...     2020/Jun     2020/Jul
# Unidade da Federação                        ...
# 13 Amazonas            35752.72   45570.64  ...  17509334.66  13358514.02
# 29 Bahia              135146.36  448349.75  ...  65159300.63  58898100.40
# 53 Distrito Federal   191951.47  769966.25  ...  23479773.03  22233542.26
# 35 São Paulo         1665349.90 4434168.64  ... 299060851.62 282709570.31
# 43 Rio Grande do Sul 1049252.33 3182913.14  ...  89019478.82  78929703.81
#
# [5 rows x 156 columns]

# %%
ax = states5.T.plot(figsize=(12,8))
ax.set_title('Gastos do SUS por unidade da Federação')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.show()

# %% [markdown]
# Tratando o dado de 1 bilhão que está errado no Estado de SP

# %%
states5
# Out:
#                        2007/Ago   2007/Set  ...     2020/Jun     2020/Jul
# Unidade da Federação                        ...
# 13 Amazonas            35752.72   45570.64  ...  17509334.66  13358514.02
# 29 Bahia              135146.36  448349.75  ...  65159300.63  58898100.40
# 53 Distrito Federal   191951.47  769966.25  ...  23479773.03  22233542.26
# 35 São Paulo         1665349.90 4434168.64  ... 299060851.62 282709570.31
# 43 Rio Grande do Sul 1049252.33 3182913.14  ...  89019478.82  78929703.81
#
# [5 rows x 156 columns]

# %%
states5.iloc[3,5]  = states5['2008/Jan'].mean()

# %%
ax = states5.T.plot(figsize=(12,8))
ax.set_title('Gastos do SUS por unidade da Federação')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
ax.legend(bbox_to_anchor=(1,1), loc='upper left')
plt.show()

# %% [markdown]
# Podemos usar o .legend() do Matplotlib para ajustar a posição da nossa legenda como fiz nos gráficos acima.
# Com os parâmetros bbox_to_anchor e loc
